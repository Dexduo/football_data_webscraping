# %%
import pandas as pd

# %%
dataset = pd.read_csv('brasileirao_2025.csv')

# %%
dataset = dataset.drop('Unnamed: 0', axis=1)

# %%
dataset[dataset['Time casa'] == 'Fortaleza EC']
# Out:
#         Time casa    Time visitante  Gols casa  Gols visitante  \
# 3    Fortaleza EC     Fluminense FC          2               0
# 27   Fortaleza EC  SC Internacional          0               0
# 45   Fortaleza EC      SE Palmeiras          1               2
# 67   Fortaleza EC      EC Juventude          5               0
# 94   Fortaleza EC       Cruzeiro EC          0               2
# 107  Fortaleza EC         Santos FC          2               3
# 121  Fortaleza EC          Ceará SC          0               1
# 134  Fortaleza EC          EC Bahia          1               1
# 156  Fortaleza EC     RB Bragantino          3               1
# 177  Fortaleza EC       Botafogo FR          0               5
# 199  Fortaleza EC       Mirassol FC          0               1
# 214  Fortaleza EC        EC Vitória          2               0
# 233  Fortaleza EC      Sport Recife          1               0
# 251  Fortaleza EC      São Paulo FC          0               2
# ...

# %%
dataset[dataset['Time casa'] == 'Fortaleza EC']['Impedimentos casa'].mean()
# Out:
# np.float64(1.8421052631578947)

# %%
dataset[dataset['Time casa'] == 'Fortaleza EC']['Impedimentos visitante'].mean()
# Out:
# np.float64(1.631578947368421)

# %%
dataset[dataset['Time visitante'] == 'Fortaleza EC']['Impedimentos visitante'].mean()
# Out:
# np.float64(1.894736842105263)

# %%
dataset[dataset['Time visitante'] == 'Fortaleza EC']['Impedimentos casa'].mean()
# Out:
# np.float64(2.0)
